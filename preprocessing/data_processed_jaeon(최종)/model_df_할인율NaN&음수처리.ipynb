# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import datetime

# 불필요한 경고문 생략(선택)
import warnings
warnings.filterwarnings('ignore')

# 모든 컬럼 출력설정(선택)
pd.set_option('display.max_columns', None)

df = pd.read_csv('model_df.csv')
df.isna().sum()
# Out:
# 기획년도             0
# 주차               0
# 카테고리             0
# 라인               0
# 시즌이월             0
# 시즌               0
# 복종               0
# 소품종              0
# 성별               0
# 총입고수량            0
# 판매수량             0
# 판매액              0
# 평균택가             0
# 평균원가             0
# 총입고원가            0
# 총입고택가            0
# 매출원가계            0
# 판매택가계            0
# 주차별_평균_실판매가    300
# 월                0
# 월별_평균_실판매가      89
# 시즌별_평균_실판매가      0
# 실판매가            20
# 할인율             20
# 누적판매수량           0
# 누적판매액            0
# 누적매출원가           0
# 누적판매택가           0
# 누적판매율            0
# ROI              0
# 맑음               0
# 흐림               0
# 비                0
# 강한 비             0
# 눈                0
# 강한 눈             0
# 진눈깨비             0
# 악천후일수            0
# 평균기온(도)          0
# dtype: int64

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)
df[condition]
# Out:
#       기획년도          주차               카테고리  라인   시즌이월   시즌   복종       소품종  \
# 22    2021  2021-01-10       봄_코트_싱글코트_ZB  ZB  01_시즌    봄   코트      싱글코트
# 44    2021  2021-01-17       봄_코트_더블코트_ZB  ZB  01_시즌    봄   코트      더블코트
# 196   2021  2021-02-21  여름_수트_블레이져(수트)_ZC  ZC  01_시즌   여름   수트  블레이져(수트)
# 198   2021  2021-02-21      여름_수트_수트팬츠_ZC  ZC  01_시즌   여름   수트      수트팬츠
# 201   2021  2021-02-21        여름_점퍼_점퍼_ZB  ZB  01_시즌   여름   점퍼        점퍼
# ...    ...         ...                ...  ..    ...  ...  ...       ...
# 6995  2024  2024-04-07       봄_자켓_싱글재킷_ZB  ZB  01_시즌    봄   자켓      싱글재킷
# 8134  2024  2024-09-22        여름_점퍼_점퍼_ZB  ZB  01_시즌   여름   점퍼        점퍼
# 8261  2024  2024-10-06   겨울_스웨터_Turtle_ZB  ZB  01_시즌   겨울  스웨터    Turtle
# 8270  2024  2024-10-06      겨울_코트_싱글코트_ZB  ZB  01_시즌   겨울   코트      싱글코트
# 8840  2024  2024-12-29     사계절_데님_데님팬츠_ZB  ZB  01_시즌  사계절   데님      데님팬츠
#
#         성별  총입고수량  판매수량       판매액    평균택가   평균원가      총입고원가       총입고택가  \
# ...

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)

df.loc[condition, '실판매가'] = df.loc[condition, '주차별_평균_실판매가']
df.loc[condition, '할인율'] = (1 - df.loc[condition, '실판매가'] / df.loc[condition, '평균택가']) * 100

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)
df[condition]
# Out:
#       기획년도          주차                     카테고리  라인   시즌이월   시즌     복종  \
# 22    2021  2021-01-10             봄_코트_싱글코트_ZB  ZB  01_시즌    봄     코트
# 44    2021  2021-01-17             봄_코트_더블코트_ZB  ZB  01_시즌    봄     코트
# 393   2021  2021-03-28           여름_스웨터_T-에리_ZB  ZB  01_시즌   여름    스웨터
# 1028  2021  2021-07-25          가을_니트 셔츠_라운드_ZB  ZB  01_시즌   가을  니트 셔츠
# 1045  2021  2021-08-01        여름_수트_블레이져(수트)_ZA  ZA  01_시즌   여름     수트
# 1165  2021  2021-08-22            여름_수트_수트팬츠_ZB  ZB  01_시즌   여름     수트
# 1221  2021  2021-08-29       사계절_우븐 셔츠_드레스셔츠_ZC  ZC  01_시즌  사계절  우븐 셔츠
# 1305  2021  2021-09-12           사계절_자켓_싱글재킷_ZB  ZB  01_시즌  사계절     자켓
# 1338  2021  2021-09-12          겨울_사파리_패딩사파리_ZB  ZB  01_시즌   겨울    사파리
# 1471  2021  2021-10-03            겨울_코트_싱글코트_ZA  ZA  01_시즌   겨울     코트
# 1611  2021  2021-10-24           사계절_자켓_싱글재킷_ZB  ZB  01_시즌  사계절     자켓
# 2082  2022  2022-01-16           사계절_팬츠_니트팬츠_ZB  ZB  01_시즌  사계절     팬츠
# ...

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)

df.loc[condition, '실판매가'] = df.loc[condition, '월별_평균_실판매가']
df.loc[condition, '할인율'] = (1 - df.loc[condition, '실판매가'] / df.loc[condition, '평균택가']) * 100

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)
df[condition]
# Out:
#       기획년도          주차              카테고리  라인   시즌이월   시즌     복종   소품종    성별  \
# 393   2021  2021-03-28    여름_스웨터_T-에리_ZB  ZB  01_시즌   여름    스웨터  T-에리  1:남성
# 5439  2023  2023-07-30  사계절_니트 셔츠_라운드_ZB  ZB  01_시즌  사계절  니트 셔츠   라운드  1:남성
#
#       총입고수량  판매수량       판매액   평균택가  평균원가      총입고원가       총입고택가   매출원가계  \
# 393   31276   -76 -18573431  89900  8224  257229462  2811712400 -625062
# 5439   8765    -4  -1389760  79900  7430   65123950   700323500  -29720
#
#         판매택가계  주차별_평균_실판매가  월  월별_평균_실판매가  시즌별_평균_실판매가      실판매가        할인율  \
# 393  -6832400     244387.0  3    151222.0        41028  151222.0 -68.211346
# 5439  -319600     347440.0  7     93621.0        37400   93621.0 -17.172716
#
#       누적판매수량      누적판매액    누적매출원가     누적판매택가  누적판매율   ROI  맑음  흐림  비  강한 비  눈  \
# 393     1050   46799119   7684818   94395000   3.36  0.14   5   1  1     0  0
# 5439    7111  204851147  52834730  568168900  81.13  2.05   5   1  0     1  0
#
#       강한 눈  진눈깨비  악천후일수  평균기온(도)
# ...

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)

df.loc[condition, '실판매가'] = df.loc[condition, '시즌별_평균_실판매가']
df.loc[condition, '할인율'] = (1 - df.loc[condition, '실판매가'] / df.loc[condition, '평균택가']) * 100

# %%
condition = (df['할인율'].isna()) | (df['할인율'] < 0)
df[condition]
# Out:
# Empty DataFrame
# Columns: [기획년도, 주차, 카테고리, 라인, 시즌이월, 시즌, 복종, 소품종, 성별, 총입고수량, 판매수량, 판매액, 평균택가, 평균원가, 총입고원가, 총입고택가, 매출원가계, 판매택가계, 주차별_평균_실판매가, 월, 월별_평균_실판매가, 시즌별_평균_실판매가, 실판매가, 할인율, 누적판매수량, 누적판매액, 누적매출원가, 누적판매택가, 누적판매율, ROI, 맑음, 흐림, 비, 강한 비, 눈, 강한 눈, 진눈깨비, 악천후일수, 평균기온(도)]
# Index: []

# %%
df.to_csv("model_df_할인율NaN음수처리", index=False, encoding='utf-8-sig')
